# %% [markdown]
# # Start of Project

# %%
import pandas as pd

# Customer unique id isn't unique
df_customer = pd.read_csv("./data/olist_customers_dataset.csv")
df_customer
# Out:
#                             customer_id                customer_unique_id  \
# 0      06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1      18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2      4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3      b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4      4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
# ...                                 ...                               ...
# 99436  17ddf5dd5d51696bb3d7c6291687be6f  1a29b476fee25c95fbafc67c5ac95cf8
# 99437  e7b71a9017aa05c9a7fd292d714858e8  d52a67c98be1cf6a5c84435bd38d095d
# 99438  5e28dfe12db7fb50a4b2f691faecea5e  e9f50caf99f032f0bf3c55141f019d99
# 99439  56b18e2166679b8a959d72dd06da27f9  73c2643a0a458b49f58cea58833b192e
# 99440  274fa6071e5e17fe303b9748641082c8  84732c5050c01db9b23e19ba39899398
#
#        customer_zip_code_prefix          customer_city customer_state
# ...

# %%
df_orders = pd.read_csv("./data/olist_orders_dataset.csv")
df_orders
# Out:
#                                order_id                       customer_id  \
# 0      e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1      53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2      47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3      949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4      ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                 ...                               ...
# 99436  9c5dedf39a927c1b2549525ed64a053c  39bd1228ee8140590ac3aca26f2dfe00
# 99437  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 99438  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 99439  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 99440  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#       order_status order_purchase_timestamp    order_approved_at  \
# ...

# %%
df_cutomers_with_orders = df_orders.merge(df_customer, on="customer_id")
df_cutomers_with_orders
# Out:
#                                order_id                       customer_id  \
# 0      e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1      53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2      47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3      949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4      ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                 ...                               ...
# 99436  9c5dedf39a927c1b2549525ed64a053c  39bd1228ee8140590ac3aca26f2dfe00
# 99437  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 99438  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 99439  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 99440  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#       order_status order_purchase_timestamp    order_approved_at  \
# ...

# %%
df_cutomers_with_orders.groupby(by = ["customer_unique_id"]).count()
# Out:
#                                   order_id  customer_id  order_status  \
# customer_unique_id
# 0000366f3b9a7992bf8c76cfdf3221e2         1            1             1
# 0000b849f77a49e4a4ce2b2a4ca5be3f         1            1             1
# 0000f46a3911fa3c0805444483337064         1            1             1
# 0000f6ccb0745a6a4b88665a16c9f078         1            1             1
# 0004aac84e0df4da2b147fca70cf8255         1            1             1
# ...                                    ...          ...           ...
# fffcf5a5ff07b0908bd4e2dbc735a684         1            1             1
# fffea47cd6d3cc0a88bd621562a9d061         1            1             1
# ffff371b4d645b6ecea244b27531430a         1            1             1
# ffff5962728ec6157033ef9805bacc48         1            1             1
# ffffd2657e2aad2907e67c3e9daecbeb         1            1             1
#
#                                   order_purchase_timestamp  order_approved_at  \
# customer_unique_id
# ...

# %%
df_orders["customer_id"].nunique()
# Out:
# 99441

# %%
df_order_by_customer_id =  df_cutomers_with_orders.groupby(by = ["customer_unique_id"]).count()
df_order_by_customer_id[df_order_by_customer_id ["order_id"] > 1]
# Out:
#                                   order_id  customer_id  order_status  \
# customer_unique_id
# 00172711b30d52eea8b313a7f2cced02         2            2             2
# 004288347e5e88a27ded2bb23747066c         2            2             2
# 004b45ec5c64187465168251cd1c9c2f         2            2             2
# 0058f300f57d7b93c477a131a59b36c3         2            2             2
# 00a39521eb40f7012db50455bf083460         2            2             2
# ...                                    ...          ...           ...
# ff36be26206fffe1eb37afd54c70e18b         3            3             3
# ff44401d0d8f5b9c54a47374eb48c1b8         2            2             2
# ff8892f7c26aa0446da53d01b18df463         2            2             2
# ff922bdd6bafcdf99cb90d7f39cea5b3         3            3             3
# ffe254cc039740e17dd15a5305035928         2            2             2
#
#                                   order_purchase_timestamp  order_approved_at  \
# customer_unique_id
# ...

# %%
df_money = pd.read_csv("./data/olist_order_items_dataset.csv")
df_money
# Out:
#                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214              1
# 1       00018f77f2f0320c557190d7a144bdd3              1
# 2       000229ec398224ef6ca0657da4fc703e              1
# 3       00024acbcdf0a6daa1e931b038114c75              1
# 4       00042b26cf59d7ce69dfabb4e55b4fd9              1
# ...                                  ...            ...
# 112645  fffc94f6ce00a00581880bf54a75a037              1
# 112646  fffcd46ef2263f404302a634eb57f7eb              1
# 112647  fffce4705a9662cd70adb13d4a31832d              1
# 112648  fffe18544ffabc95dfada21779c9644f              1
# 112649  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id                         seller_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1       e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# ...

# %%
df_money[["order_id", "price"]].groupby(by = "order_id").mean()
# Out:
#                                    price
# order_id
# 00010242fe8c5a6d1ba2dd792cb16214   58.90
# 00018f77f2f0320c557190d7a144bdd3  239.90
# 000229ec398224ef6ca0657da4fc703e  199.00
# 00024acbcdf0a6daa1e931b038114c75   12.99
# 00042b26cf59d7ce69dfabb4e55b4fd9  199.90
# ...                                  ...
# fffc94f6ce00a00581880bf54a75a037  299.99
# fffcd46ef2263f404302a634eb57f7eb  350.00
# fffce4705a9662cd70adb13d4a31832d   99.90
# fffe18544ffabc95dfada21779c9644f   55.99
# fffe41c64501cc87c801fd61db3f6244   43.00
#
# [98666 rows x 1 columns]

# %%
df_order_by_customer_id
# Out:
#                                   order_id  order_status  \
# customer_id
# 00012a2ce6f8dcda20d059ce98491703         1             1
# 000161a058600d5901f007fab4c27140         1             1
# 0001fd6190edaaf884bcaf3d49edf079         1             1
# 0002414f95344307404f0ace7a26f1d5         1             1
# 000379cdec625522490c315e70c7a9fb         1             1
# ...                                    ...           ...
# fffecc9f79fd8c764f843e9951b11341         1             1
# fffeda5b6d849fbd39689bb92087f431         1             1
# ffff42319e9b2d713724ae527742af25         1             1
# ffffa3172527f765de70084a7e53aae8         1             1
# ffffe8b65bbe3087b653a978c870db99         1             1
#
#                                   order_purchase_timestamp  order_approved_at  \
# customer_id
# 00012a2ce6f8dcda20d059ce98491703                         1                  1
# 000161a058600d5901f007fab4c27140                         1                  1
# ...
